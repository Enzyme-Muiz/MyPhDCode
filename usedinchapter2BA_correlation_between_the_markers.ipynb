# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\oaona\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv("playR_concattransformed_all.csv", index_col=0)
data.columns
# Out:
# Index(['KLF10', 'CD19', 'CD5', 'MYC', 'CD83', 'IgD', 'NR4A2', 'PPP1R15A',
#        'JUND', 'FOSB', 'CD21', 'RGS1', 'CD27', 'KLF6', 'CD22', 'TCL1A',
#        'DDIT3', 'Ki67', 'YPEL5', 'HSPA5', 'TXNIP', 'CD38', 'RGS2', 'EGR1',
#        'IgM', 'CD69', 'FOS', 'CXCR4', 'Actin', 'labels'],
#       dtype='object')

# %%
data = data.drop('labels', axis = 1)

# %%
correlation_matrix = data.corr(method='spearman')

# %%
# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, 
            #annot=True, 
            cmap='coolwarm', 
            linewidths=0.5)
plt.title('Spearman Correlation Heatmap of the Markers')
plt.show()

# %%
sorted_df = correlation_matrix.stack().reset_index().rename(columns={0: 'Value'})
sorted_df = sorted_df.sort_values(by='Value', ascending=False)

# Get the top 10 distinct highest values
top_10_distinct_values = sorted_df['Value'].unique()[:10]

print(top_10_distinct_values)
# Out:
# [1.         0.54163005 0.52186347 0.50476268 0.44674164 0.42087618
#  0.42064574 0.41258314 0.40731935 0.38366133]

# %%
sorted_df.head(50)
# Out:
#       level_0   level_1     Value
# 0       KLF10     KLF10  1.000000
# 450     TCL1A     TCL1A  1.000000
# 90        MYC       MYC  1.000000
# 120      CD83      CD83  1.000000
# 150       IgD       IgD  1.000000
# 180     NR4A2     NR4A2  1.000000
# 210  PPP1R15A  PPP1R15A  1.000000
# 240      JUND      JUND  1.000000
# 270      FOSB      FOSB  1.000000
# 300      CD21      CD21  1.000000
# 330      RGS1      RGS1  1.000000
# 360      CD27      CD27  1.000000
# 390      KLF6      KLF6  1.000000
# 480     DDIT3     DDIT3  1.000000
# 30       CD19      CD19  1.000000
# 510      Ki67      Ki67  1.000000
# 540     YPEL5     YPEL5  1.000000
# 570     HSPA5     HSPA5  1.000000
# 600     TXNIP     TXNIP  1.000000
# 630      CD38      CD38  1.000000
# 660      RGS2      RGS2  1.000000
# 690      EGR1      EGR1  1.000000
# 720       IgM       IgM  1.000000
# 750      CD69      CD69  1.000000
# 780       FOS       FOS  1.000000
# 810     CXCR4     CXCR4  1.000000
# 60        CD5       CD5  1.000000
# 420      CD22      CD22  1.000000
# 840     Actin     Actin  1.000000
# 42       CD19      KLF6  0.541630
# 378      KLF6      CD19  0.541630
# 407      CD22      CD19  0.521863
# 43       CD19      CD22  0.521863
# 70        CD5      CD27  0.504763
# 350      CD27       CD5  0.504763
# 749      CD69       IgM  0.446742
# 721       IgM      CD69  0.446742
# 697       IgM      CD19  0.420876
# 53       CD19       IgM  0.420876
# 63        CD5       IgD  0.420646
# 147       IgD       CD5  0.420646
# 468     DDIT3      CD83  0.412583
# 132      CD83     DDIT3  0.412583
# 430      CD22       IgM  0.407319
# 710       IgM      CD22  0.407319
# 39       CD19      CD21  0.383661
# 291      CD21      CD19  0.383661
# 169       IgD       IgM  0.383300
# 701       IgM       IgD  0.383300
# 358      CD27      CD21  0.381037
